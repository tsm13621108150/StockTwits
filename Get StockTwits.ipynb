# %%
import requests
import json

url="https://api.stocktwits.com/api/2/streams/symbol/SPX.json"
req=requests.get(url)
obj=req.json()

# %%
print(obj)
# Out:
# {'response': {'status': 200}, 'symbol': {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37481}, 'cursor': {'more': True, 'since': 152546553, 'max': 152540295}, 'messages': [{'id': 152546553, 'body': '$SPX $AAPL $FB $QQQ $UVXY $TVIX $VIX $TSLA $TWTR $FIT $TGT $WMT Our latest State Of The Market W/Seth &amp; Wayne https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'created_at': '2019-02-02T17:21:39Z', 'user': {'id': 812524, 'username': 'sethmarcus', 'name': 'seth marcus gold', 'avatar_url': 'https://avatars.stocktwits.com/production/812524/thumb-1525518672.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/812524/thumb-1525518672.png', 'join_date': '2016-08-05', 'official': False, 'identity': 'User', 'classification': [], 'followers': 1974, 'following': 286, 'ideas': 36112, 'watchlist_stocks_count': 12, 'like_count': 15106}, 'source': {'id': 2269, 'title': 'StockTwits Web', 'url': 'https://stocktwits.com'}, 'symbols': [{'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37481}, {'id': 680, 'symbol': 'VIX', 'title': 'CBOE Volatility Index', 'aliases': [], 'is_following': False, 'watchlist_count': 14552}, {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 282454}, {'id': 7396, 'symbol': 'TGT', 'title': 'Target Corp.', 'aliases': [], 'is_following': False, 'watchlist_count': 14610}, {'id': 7745, 'symbol': 'WMT', 'title': 'Walmart Stores Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 40504}, {'id': 7871, 'symbol': 'FB', 'title': 'Facebook', 'aliases': ['FBOOK'], 'is_following': False, 'watchlist_count': 201727}, {'id': 7872, 'symbol': 'TWTR', 'title': 'Twitter', 'aliases': ['TWIT'], 'is_following': False, 'watchlist_count': 127989}, {'id': 8660, 'symbol': 'TSLA', 'title': 'Tesla, Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 197896}, {'id': 9466, 'symbol': 'TVIX', 'title': 'VelocityShares Daily 2x VIX ST ETN', 'aliases': [], 'is_following': False, 'watchlist_count': 32294}, {'id': 9581, 'symbol': 'QQQ', 'title': 'PowerShares Nasdaq-100 QQQ', 'aliases': ['QQQQ'], 'is_following': False, 'watchlist_count': 38388}, {'id': 11188, 'symbol': 'UVXY', 'title': 'ProShares Trust Ultra VIX Short-Term Futures ETF', 'aliases': [], 'is_following': False, 'watchlist_count': 37299}, {'id': 12600, 'symbol': 'FIT', 'title': 'Fitbit', 'aliases': [], 'is_following': False, 'watchlist_count': 40883}], 'links': [{'title': 'State of the Market With Wayne & Seth: 1/31/19 - Finom Group', 'url': 'https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'shortened_url': 'https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'shortened_expanded_url': 'finomgroup.com/state-of-the...', 'description': 'Welcome to our latest State of the Market (SOTM). Please click the link to view the video. (58 minutes in duration) Outline: Introduction (0-3 minutes FOMC/Fed meeting, revert to data dependency, no rate hike, what was removed in statement, usual behavior of the Fed, market reaction to Fed, no catalyst for inflation via PCE Index warrants Fed pause, policy error ...', 'image': 'https://www.finomgroup.com/wp-content/uploads/2019/02/Screen-Shot-2019-02-01-at-4.56.15-AM.png', 'created_at': '2019-02-02T17:21:40Z', 'video_url': None, 'source': {'name': 'Finom Group', 'website': 'https://www.finomgroup.com'}}], 'mentioned_users': [], 'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_152546553.png', 'large': 'https://charts.stocktwits.com/production/large_152546553.png', 'original': 'https://charts.stocktwits.com/production/original_152546553.png', 'url': 'https://charts.stocktwits.com/production/original_152546553.png'}, 'sentiment': None}}, {'id': 152546493, 'body': '$SPY $SPX $FB $AAPL $AMZN $NFLX $GOOGL\n\nTrump: Xi stop playing around and lets make a ...

# %%
print(type(obj))
# Out:
# <class 'dict'>

# %%
print(obj.keys())
# Out:
# dict_keys(['response', 'symbol', 'cursor', 'messages'])

# %%
print(obj['response'])
# Out:
# {'status': 200}

# %%
print(obj['symbol'])
# Out:
# {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37481}

# %% [markdown]
# Just want the symbol from this.

# %%
print(obj['cursor'])
# Out:
# {'more': True, 'since': 152546553, 'max': 152540295}

# %% [markdown]
# Don't want to keep this.

# %%
print(obj['messages'])
# Out:
# [{'id': 152546553, 'body': '$SPX $AAPL $FB $QQQ $UVXY $TVIX $VIX $TSLA $TWTR $FIT $TGT $WMT Our latest State Of The Market W/Seth &amp; Wayne https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'created_at': '2019-02-02T17:21:39Z', 'user': {'id': 812524, 'username': 'sethmarcus', 'name': 'seth marcus gold', 'avatar_url': 'https://avatars.stocktwits.com/production/812524/thumb-1525518672.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/812524/thumb-1525518672.png', 'join_date': '2016-08-05', 'official': False, 'identity': 'User', 'classification': [], 'followers': 1974, 'following': 286, 'ideas': 36112, 'watchlist_stocks_count': 12, 'like_count': 15106}, 'source': {'id': 2269, 'title': 'StockTwits Web', 'url': 'https://stocktwits.com'}, 'symbols': [{'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37481}, {'id': 680, 'symbol': 'VIX', 'title': 'CBOE Volatility Index', 'aliases': [], 'is_following': False, 'watchlist_count': 14552}, {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 282454}, {'id': 7396, 'symbol': 'TGT', 'title': 'Target Corp.', 'aliases': [], 'is_following': False, 'watchlist_count': 14610}, {'id': 7745, 'symbol': 'WMT', 'title': 'Walmart Stores Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 40504}, {'id': 7871, 'symbol': 'FB', 'title': 'Facebook', 'aliases': ['FBOOK'], 'is_following': False, 'watchlist_count': 201727}, {'id': 7872, 'symbol': 'TWTR', 'title': 'Twitter', 'aliases': ['TWIT'], 'is_following': False, 'watchlist_count': 127989}, {'id': 8660, 'symbol': 'TSLA', 'title': 'Tesla, Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 197896}, {'id': 9466, 'symbol': 'TVIX', 'title': 'VelocityShares Daily 2x VIX ST ETN', 'aliases': [], 'is_following': False, 'watchlist_count': 32294}, {'id': 9581, 'symbol': 'QQQ', 'title': 'PowerShares Nasdaq-100 QQQ', 'aliases': ['QQQQ'], 'is_following': False, 'watchlist_count': 38388}, {'id': 11188, 'symbol': 'UVXY', 'title': 'ProShares Trust Ultra VIX Short-Term Futures ETF', 'aliases': [], 'is_following': False, 'watchlist_count': 37299}, {'id': 12600, 'symbol': 'FIT', 'title': 'Fitbit', 'aliases': [], 'is_following': False, 'watchlist_count': 40883}], 'links': [{'title': 'State of the Market With Wayne & Seth: 1/31/19 - Finom Group', 'url': 'https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'shortened_url': 'https://www.finomgroup.com/state-of-the-market-with-wayne-seth-1-31-19/', 'shortened_expanded_url': 'finomgroup.com/state-of-the...', 'description': 'Welcome to our latest State of the Market (SOTM). Please click the link to view the video. (58 minutes in duration) Outline: Introduction (0-3 minutes FOMC/Fed meeting, revert to data dependency, no rate hike, what was removed in statement, usual behavior of the Fed, market reaction to Fed, no catalyst for inflation via PCE Index warrants Fed pause, policy error ...', 'image': 'https://www.finomgroup.com/wp-content/uploads/2019/02/Screen-Shot-2019-02-01-at-4.56.15-AM.png', 'created_at': '2019-02-02T17:21:40Z', 'video_url': None, 'source': {'name': 'Finom Group', 'website': 'https://www.finomgroup.com'}}], 'mentioned_users': [], 'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_152546553.png', 'large': 'https://charts.stocktwits.com/production/large_152546553.png', 'original': 'https://charts.stocktwits.com/production/original_152546553.png', 'url': 'https://charts.stocktwits.com/production/original_152546553.png'}, 'sentiment': None}}, {'id': 152546493, 'body': '$SPY $SPX $FB $AAPL $AMZN $NFLX $GOOGL\n\nTrump: Xi stop playing around and lets make a deal!\n\nXi:', 'created_at': '2019-02-02T17:20:02Z', 'user': {'id': 1486894, 'username': 'TheNamelessKing', 'name': 'Darksoul Stocks', 'avatar_url': 'https://avatars.stocktwits.com/production/1486894/thumb-1549069256.png', 'avatar_url_ ...

# %%
len(obj['messages'])
# Out:
# 30

# %%
[obj['messages'][k]['entities']['sentiment'] for k in range(30)]
# Out:
# [None,
#  None,
#  None,
#  {'basic': 'Bearish'},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  {'basic': 'Bullish'},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
obj['messages'][3]
# Out:
# {'id': 152545993,
#  'body': '$SPY $SPX Chart in the link below.',
#  'created_at': '2019-02-02T17:06:17Z',
#  'user': {'id': 1398211,
#   'username': 'TrendSpider',
#   'name': 'TrendSpider',
#   'avatar_url': 'https://avatars.stocktwits.com/production/1398211/thumb-1529986157.png',
#   'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1398211/thumb-1529986157.png',
#   'join_date': '2018-02-03',
#   'official': False,
#   'identity': 'User',
#   'classification': [],
#   'followers': 1661,
#   'following': 59,
#   'ideas': 5290,
#   'watchlist_stocks_count': 0,
#   'like_count': 861},
#  'source': {'id': 2269,
#   'title': 'StockTwits Web',
#   'url': 'https://stocktwits.com'},
#  'symbols': [{'id': 679,
#    'symbol': 'SPX',
#    'title': 'S&P 500 Index',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 37481},
#   {'id': 7271,
#    'symbol': 'SPY',
#    'title': 'SPDR S&P 500',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 112392}],
#  'conversation': {'parent_message_id': 152545993,
#   'in_reply_to_message_id': None,
#   'parent': True,
#   'replies': 1},
#  'likes': {'total': 1, 'user_ids': [1774444]},
#  'mentioned_users': [],
#  'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_152545993.PNG',
#    'large': 'https://charts.stocktwits.com/production/large_152545993.PNG',
#    'original': 'https://charts.stocktwits.com/production/original_152545993.PNG',
#    'url': 'https://charts.stocktwits.com/production/original_152545993.PNG'},
#   'sentiment': None}}

# %%
import requests
import time
import json

symbolList = ['SPX', 'DJIA', 'SPY', 'QQQ', 'AAPL', 'GOOG', 'FB', 'AMZN', 'JPM', 'WFC', 'BA', 'TWTR', 'BLK', 'DIA', 'MSFT', 'AMD', 'BRK.B', 'JNJ', 'XOM', 'BAC', 'CVX', 'PG', 'T', 'HD', 'PFE', 'UNH', 'V', 'VZ', 'C', 'INTC', 'CSCO', 'CMCSA', 'GOOGL', 'NVDA', 'AMGN', 'TXN', 'AVGO', 'DIS', 'GILD', 'QCOM', 'NFLX', 'PYPL', 'KHC', 'ADBE', 'PCLN', 'CHTR', 'SBUX', 'WMT', 'TGT', 'COST', 'CELG', 'WBA', 'MMM', 'AXP', 'CAT', 'GE', 'GS', 'IBM', 'MCD', 'MRK', 'NKE', 'TRV', 'ABBV', 'ABT', 'AIG', 'ALL', 'BIIB', 'BK', 'BMY', 'CL', 'COF', 'COP', 'CVS', 'DHR', 'DUK', 'DWDP', 'EMR', 'EXC', 'F', 'FDX', 'FOX', 'GD', 'GM', 'HAL', 'HON', 'KMI', 'KO', 'LLY', 'LMT', 'LOW', 'MA', 'MDLZ', 'MDT', 'MET', 'MO', 'MON', 'MS', 'NEE', 'ORCL', 'OXY', 'PEP', 'PM', 'RTN', 'SLB', 'SO', 'SPG', 'TWX', 'UNP', 'UPS', 'USB', 'UTX']
numSymbols = len(symbolList)

ctr=0
while ctr<10000:

    # make the request
    url="https://api.stocktwits.com/api/2/streams/symbol/"
    url=url+symbolList[ctr % numSymbols]+".json"
    r=requests.get(url)
    # check status of request
    status_code=r.status_code
    if status_code==200:

        # convert from json
        obj=r.json()
                        
        # convert the list to json
        txt=json.dumps(obj)
      
        # print it out
        fout=open('Twits.txt','a')
        fout.write(txt)
        fout.write("\r\n")
        fout.close()
    else:
        print("bad status code")

    # wait 30 seconds before making next request
    #
    time.sleep(30)
            
    # record ctr in status file
    fout2=open('status.txt','w')
    fout2.write(str(ctr))
    fout2.close()
    ctr=ctr+1
# Out:
# bad status code

# %%
with open("twitData2.txt","r") as fin:
    L=fin.readlines()
print(len(L))
L[1]

# %%
L[2]

# %%
fin=open("twitData2.txt","r")
line=fin.readline()

# %%
json.loads(line)
