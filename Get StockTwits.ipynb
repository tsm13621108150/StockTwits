# %% [markdown]
# Before running a script to get stock twits, let's see how the api works.
# To get the stock twits for a specific ticker, we put together a url as in this
# example:
#
# https://api.stocktwits.com/api/2/streams/symbol/SPX.json
#
# The response is a json string which we can convert to a Python object directly using the following.

# %%
import requests
import json

url="https://api.stocktwits.com/api/2/streams/symbol/SPX.json"
req=requests.get(url)
obj=req.json()

# %% [markdown]
# Now we try to unravel what type of object we have and how we can get information we want from it.

# %%
print(obj)
# Out:
# {'response': {'status': 200}, 'symbol': {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, 'cursor': {'more': True, 'since': 151304090, 'max': 151299551}, 'messages': [{'id': 151304090, 'body': 'Daily Plan — 1/22/2019 $SPY $ES_F $SPX https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'created_at': '2019-01-22T14:22:18Z', 'user': {'id': 1813309, 'username': 'snxfu', 'name': 'snafu', 'avatar_url': 'https://avatars.stocktwits.com/production/1813309/thumb-1547766623.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1813309/thumb-1547766623.png', 'join_date': '2019-01-17', 'official': False, 'identity': 'User', 'classification': [], 'followers': 0, 'following': 0, 'ideas': 3, 'watchlist_stocks_count': 0, 'like_count': 0}, 'source': {'id': 2269, 'title': 'StockTwits Web', 'url': 'https://stocktwits.com'}, 'symbols': [{'id': 647, 'symbol': 'ES_F', 'title': 'E-Mini S&P 500 Futures', 'aliases': [], 'is_following': False, 'watchlist_count': 8921}, {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, {'id': 7271, 'symbol': 'SPY', 'title': 'SPDR S&P 500', 'aliases': [], 'is_following': False, 'watchlist_count': 111302}], 'links': [{'title': 'Daily Plan - 1/22/2019', 'url': 'https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'shortened_url': 'https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'shortened_expanded_url': 'snafu.home.blog/2019/01/22/...', 'description': 'If 2645 breaks and stays as resistance I will be a seller looking for the test of 2635 and 2620 If 2645 holds as support I will look to be a buyer towards 2666 and 2675', 'image': 'https://snafuhome.files.wordpress.com/2019/01/descarga-2.png?fit=440%2C330', 'created_at': '2019-01-22T14:22:20Z', 'video_url': None, 'source': {'name': 'Home', 'website': 'https://snafu.home.blog'}}], 'mentioned_users': [], 'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_151304090.png', 'large': 'https://charts.stocktwits.com/production/large_151304090.png', 'original': 'https://charts.stocktwits.com/production/original_151304090.png', 'url': 'https://charts.stocktwits.com/production/original_151304090.png'}, 'sentiment': None}}, {'id': 151304029, 'body': '$SPX $DJIA $NDX $RUT $SPY WTF IS A GRAY RHINO!?!?!', 'created_at': '2019-01-22T14:21:39Z', 'user': {'id': 953086, 'username': 'SteinCapital', 'name': 'The Punisher', 'avatar_url': 'https://avatars.stocktwits.com/production/953086/thumb-1542422785.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/953086/thumb-1542422785.png', 'join_date': '2017-02-11', 'official': False, 'identity': 'User', 'classification': [], 'followers': 32, 'following': 49, 'ideas': 2406, 'watchlist_stocks_count': 11, 'like_count': 1377}, 'source': {'id': 1149, 'title': 'StockTwits for iOS', 'url': 'http://www.stocktwits.com/mobile'}, 'symbols': [{'id': 677, 'symbol': 'DJIA', 'title': 'Dow Jones Industrial Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37716}, {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, {'id': 7271, 'symbol': 'SPY', 'title': 'SPDR S&P 500', 'aliases': [], 'is_following': False, 'watchlist_count': 111302}, {'id': 9698, 'symbol': 'RUT', 'title': 'Russell 2000 Index', 'aliases': ['RUTX'], 'is_following': False, 'watchlist_count': 2407}, {'id': 11190, 'symbol': 'NDX', 'title': 'NASDAQ Composite', 'aliases': [], 'is_following': False, 'watchlist_count': 9835}], 'conversation': {'parent_message_id': 151304029, 'in_reply_to_message_id': None, 'parent': True, 'replies': 1}, 'reshare_message': {'reshared_count': 1, 'reshared_deleted': False, 'reshared_user_deleted': False, 'parent_reshared_deleted': False, 'message': {'id': 151303726, 'body': '$SPX $DJIA $NDX $RUT $SPY \nThe investor known as the ‘Warren Buffett of Boston’ rattles Davos crowd with this w ...

# %%
print(type(obj))
# Out:
# <class 'dict'>

# %%
print(obj.keys())
# Out:
# dict_keys(['response', 'symbol', 'cursor', 'messages'])

# %%
print(obj['response'])
# Out:
# {'status': 200}

# %%
print(obj['symbol'])
# Out:
# {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}

# %% [markdown]
# Just want the symbol from this.

# %%
print(obj['cursor'])
# Out:
# {'more': True, 'since': 151304090, 'max': 151299551}

# %% [markdown]
# Don't want to keep this.

# %%
print(obj['messages'])
# Out:
# [{'id': 151304090, 'body': 'Daily Plan — 1/22/2019 $SPY $ES_F $SPX https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'created_at': '2019-01-22T14:22:18Z', 'user': {'id': 1813309, 'username': 'snxfu', 'name': 'snafu', 'avatar_url': 'https://avatars.stocktwits.com/production/1813309/thumb-1547766623.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1813309/thumb-1547766623.png', 'join_date': '2019-01-17', 'official': False, 'identity': 'User', 'classification': [], 'followers': 0, 'following': 0, 'ideas': 3, 'watchlist_stocks_count': 0, 'like_count': 0}, 'source': {'id': 2269, 'title': 'StockTwits Web', 'url': 'https://stocktwits.com'}, 'symbols': [{'id': 647, 'symbol': 'ES_F', 'title': 'E-Mini S&P 500 Futures', 'aliases': [], 'is_following': False, 'watchlist_count': 8921}, {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, {'id': 7271, 'symbol': 'SPY', 'title': 'SPDR S&P 500', 'aliases': [], 'is_following': False, 'watchlist_count': 111302}], 'links': [{'title': 'Daily Plan - 1/22/2019', 'url': 'https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'shortened_url': 'https://snafu.home.blog/2019/01/22/daily-plan-1-22-2019/', 'shortened_expanded_url': 'snafu.home.blog/2019/01/22/...', 'description': 'If 2645 breaks and stays as resistance I will be a seller looking for the test of 2635 and 2620 If 2645 holds as support I will look to be a buyer towards 2666 and 2675', 'image': 'https://snafuhome.files.wordpress.com/2019/01/descarga-2.png?fit=440%2C330', 'created_at': '2019-01-22T14:22:20Z', 'video_url': None, 'source': {'name': 'Home', 'website': 'https://snafu.home.blog'}}], 'mentioned_users': [], 'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_151304090.png', 'large': 'https://charts.stocktwits.com/production/large_151304090.png', 'original': 'https://charts.stocktwits.com/production/original_151304090.png', 'url': 'https://charts.stocktwits.com/production/original_151304090.png'}, 'sentiment': None}}, {'id': 151304029, 'body': '$SPX $DJIA $NDX $RUT $SPY WTF IS A GRAY RHINO!?!?!', 'created_at': '2019-01-22T14:21:39Z', 'user': {'id': 953086, 'username': 'SteinCapital', 'name': 'The Punisher', 'avatar_url': 'https://avatars.stocktwits.com/production/953086/thumb-1542422785.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/953086/thumb-1542422785.png', 'join_date': '2017-02-11', 'official': False, 'identity': 'User', 'classification': [], 'followers': 32, 'following': 49, 'ideas': 2406, 'watchlist_stocks_count': 11, 'like_count': 1377}, 'source': {'id': 1149, 'title': 'StockTwits for iOS', 'url': 'http://www.stocktwits.com/mobile'}, 'symbols': [{'id': 677, 'symbol': 'DJIA', 'title': 'Dow Jones Industrial Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37716}, {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, {'id': 7271, 'symbol': 'SPY', 'title': 'SPDR S&P 500', 'aliases': [], 'is_following': False, 'watchlist_count': 111302}, {'id': 9698, 'symbol': 'RUT', 'title': 'Russell 2000 Index', 'aliases': ['RUTX'], 'is_following': False, 'watchlist_count': 2407}, {'id': 11190, 'symbol': 'NDX', 'title': 'NASDAQ Composite', 'aliases': [], 'is_following': False, 'watchlist_count': 9835}], 'conversation': {'parent_message_id': 151304029, 'in_reply_to_message_id': None, 'parent': True, 'replies': 1}, 'reshare_message': {'reshared_count': 1, 'reshared_deleted': False, 'reshared_user_deleted': False, 'parent_reshared_deleted': False, 'message': {'id': 151303726, 'body': '$SPX $DJIA $NDX $RUT $SPY \nThe investor known as the ‘Warren Buffett of Boston’ rattles Davos crowd with this warning.', 'created_at': '2019-01-22T14:19:01Z', 'user': {'id': 298989, 'username': 'toro365', 'name': 'Angel', 'avatar_url': 'https://avatars.stocktwits.com/production/298989/thumb-1430268010.png', 'avatar_url_ssl': 'https://avatars.sto ...

# %%
len(obj['messages'])
# Out:
# 30

# %%
[obj['messages'][k]['entities']['sentiment'] for k in range(30)]
# Out:
# [None,
#  None,
#  None,
#  {'basic': 'Bearish'},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  {'basic': 'Bullish'},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
obj['messages'][3]
# Out:
# {'id': 151303726,
#  'body': '$SPX $DJIA $NDX $RUT $SPY \nThe investor known as the ‘Warren Buffett of Boston’ rattles Davos crowd with this warning.',
#  'created_at': '2019-01-22T14:19:01Z',
#  'user': {'id': 298989,
#   'username': 'toro365',
#   'name': 'Angel',
#   'avatar_url': 'https://avatars.stocktwits.com/production/298989/thumb-1430268010.png',
#   'avatar_url_ssl': 'https://avatars.stocktwits.com/production/298989/thumb-1430268010.png',
#   'join_date': '2014-01-10',
#   'official': False,
#   'identity': 'User',
#   'classification': [],
#   'followers': 479,
#   'following': 15,
#   'ideas': 6045,
#   'watchlist_stocks_count': 86,
#   'like_count': 3487},
#  'source': {'id': 2095,
#   'title': 'StockTwits For Android ',
#   'url': 'http://www.stocktwits.com/mobile'},
#  'symbols': [{'id': 677,
#    'symbol': 'DJIA',
#    'title': 'Dow Jones Industrial Index',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 37716},
#   {'id': 679,
#    'symbol': 'SPX',
#    'title': 'S&P 500 Index',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 37218},
#   {'id': 7271,
#    'symbol': 'SPY',
#    'title': 'SPDR S&P 500',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 111302},
#   {'id': 9698,
#    'symbol': 'RUT',
#    'title': 'Russell 2000 Index',
#    'aliases': ['RUTX'],
#    'is_following': False,
#    'watchlist_count': 2407},
#   {'id': 11190,
#    'symbol': 'NDX',
#    'title': 'NASDAQ Composite',
#    'aliases': [],
#    'is_following': False,
#    'watchlist_count': 9835}],
#  'conversation': {'parent_message_id': 151303726,
#   'in_reply_to_message_id': None,
#   'parent': True,
#   'replies': 1},
#  'likes': {'total': 1, 'user_ids': [1478933]},
#  'reshares': {'reshared_count': 1, 'user_ids': [953086]},
#  'mentioned_users': [],
#  'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_151303726.png',
#    'large': 'https://charts.stocktwits.com/production/large_151303726.png',
#    'original': 'https://charts.stocktwits.com/production/original_151303726.png',
#    'url': 'https://charts.stocktwits.com/production/original_151303726.png'},
#   'sentiment': {'basic': 'Bearish'}}}

# %% [markdown]
# This list is what we want to store, so we convert the list to a json string and append that string to a file.

# %%
import requests
import time
import json

symbolList = ['SPX', 'DJIA', 'SPY', 'QQQ', 'AAPL', 'GOOG', 'FB', 'AMZN', 'JPM', 'WFC', 'BA', 'TWTR', 'BLK', 'DIA', 'MSFT', 'AMD', 'BRK.B', 'JNJ', 'XOM', 'BAC', 'CVX', 'PG', 'T', 'HD', 'PFE', 'UNH', 'V', 'VZ', 'C', 'INTC', 'CSCO', 'CMCSA', 'GOOGL', 'NVDA', 'AMGN', 'TXN', 'AVGO', 'DIS', 'GILD', 'QCOM', 'NFLX', 'PYPL', 'KHC', 'ADBE', 'PCLN', 'CHTR', 'SBUX', 'WMT', 'TGT', 'COST', 'CELG', 'WBA', 'MMM', 'AXP', 'CAT', 'GE', 'GS', 'IBM', 'MCD', 'MRK', 'NKE', 'TRV', 'ABBV', 'ABT', 'AIG', 'ALL', 'BIIB', 'BK', 'BMY', 'CL', 'COF', 'COP', 'CVS', 'DHR', 'DUK', 'DWDP', 'EMR', 'EXC', 'F', 'FDX', 'FOX', 'GD', 'GM', 'HAL', 'HON', 'KMI', 'KO', 'LLY', 'LMT', 'LOW', 'MA', 'MDLZ', 'MDT', 'MET', 'MO', 'MON', 'MS', 'NEE', 'ORCL', 'OXY', 'PEP', 'PM', 'RTN', 'SLB', 'SO', 'SPG', 'TWX', 'UNP', 'UPS', 'USB', 'UTX']
numSymbols = len(symbolList)

ctr=0
while ctr<10000:

    # make the request
    url="https://api.stocktwits.com/api/2/streams/symbol/"
    url=url+symbolList[ctr % numSymbols]+".json"
    r=requests.get(url)
    # check status of request
    status_code=r.status_code
    if status_code==200:

        # convert from json
        obj=r.json()
                        
        # convert the list to json
        txt=json.dumps(obj)
      
        # print it out
        fout=open('Twits.txt','a')
        fout.write(txt)
        fout.write("\r\n")
        fout.close()
    else:
        print("bad status code")

    # wait 30 seconds before making next request
    #
    time.sleep(30)
            
    # record ctr in status file
    fout2=open('status.txt','w')
    fout2.write(str(ctr))
    fout2.close()
    ctr=ctr+1

# %% [markdown]
# Note that we write each list to a file as a json string. Each json string is a single line of the file.
#
# Retrieval of the data from the file works easily enough. We read in every string as a list.

# %%
with open("twitData2.txt","r") as fin:
    L=fin.readlines()
print(len(L))
L[1]

# %% [markdown]
# Then we convert from json strings to Python objects.

# %%
L[2]

# %%
fin=open("twitData2.txt","r")
line=fin.readline()

# %%
json.loads(line)
